# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import glob

# %%
def svdCompact(A):
    m, n = A.shape
    if m > n:
        M1 = A.T@A
        D, V = np.linalg.eig(M1)
        const = n*np.max(D)*2.22e-16
        y = (D>const)
        rA = np.sum(y)
        D = y*D
        idx = D.argsort()[::-1]   
        D = D[idx]
        V = V[idx]
        Vr = V[:,:rA]
        Sr = np.diag(D[:rA])
        Ur = (1/D[:rA])*(A@Vr)
    else:
        M1 = A@A.T
        D, V = np.linalg.eig(M1)
        const = n*np.max(D)*2.22e-16
        y = (D>const)
        rA = np.sum(y)
        D = y*D
        idx = D.argsort()[::-1]   
        D = D[idx]
        U = V[idx]
        Ur = U[:,:rA]
        Sr = np.diag(D[:rA])
        Vr = (1/D[:rA]).T@A@Ur
        
    return Vr, Sr, Ur

# %%
A = np.array([[2, 1, 2], [2, -2, 2], [-2, -1, -2], [2, 0, 2]])

# %%
print(svdCompact(A))
# Out:
# (array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678],
#        [ 0.        ,  0.        ]]), array([[32.,  0.],
#        [ 0.,  6.]]), array([[ 0.06629126, -0.11785113],
#        [ 0.        , -0.47140452],
#        [-0.06629126,  0.11785113],
#        [ 0.04419417, -0.23570226]]))

# %%
def grafica_tiempos():
    dimensiones = range(5,13)
    tiempos_svd = []
    tiempos_svd_compacta = []
    for i in dimensiones:
        A = np.random.rand(i,i-1)
        start = time.time()
        np.linalg.svd(A)
        finish = time.time()
        svdCompact(A)
        finish2 = time.time()
        tiempos_svd.append(finish - start)
        tiempos_svd_compacta.append(finish2 - finish)
    
    plt.plot(dimensiones, tiempos_svd, 'r-',label="Numpy")
    plt.plot(dimensiones, tiempos_svd_compacta, 'b-', label="SVD Compacta")
    plt.title("Tiempos de ejecución de métodos de SVD")
    plt.xlabel("Dimensiones")
    plt.ylabel("Tiempo(s)")
    plt.legend()
    plt.grid()
    plt.show()

# %%
grafica_tiempos()

# %%
import PIL

# %%
S = np.empty((10304, 360))
training_folder = os.getcwd() + "/training"
idx=0
for i in range(1, 41):
    subdirectory = os.path.join(training_folder, f"s{i}")
    pattern = os.path.join(subdirectory, "*.jpg")
    files = glob.glob(pattern)
    
    for file in files:
        image = np.asarray(PIL.Image.open(file)).reshape(-1,1)
        S[:,idx:idx+1] = image
        idx+=1

# %%
A = S - S.mean(axis=1).reshape(-1,1)

# %%
U, Sr, V = np.linalg.svd(A)

# %%
def show_face(face_image):
    image = face_image.reshape(112,92)
    plt.imshow(image, cmap="gray")
    plt.axis("off")

# %%
plt.clf()
show_face(S.mean(axis=1))
plt.show()

# %%
m = len(S)
r = len((Sr > m * 2.2e-16 * Sr[0]))

# %%
x = U[:,:r].T@A

# %%
x_sample = A[:,:1]

# %%
err = np.empty(m)
for i in range(m):
    err[i]=np.linalg.norm(x_sample - x[i,:1])
err
# Out:
# array([281044.80947295,  58844.88306493, 118502.92114249, 206322.53961658,
#        114903.34750626,  78877.41713424,  57070.10094297,   7522.94122199,
#         37219.28951268, 119481.76678818,  52140.32781467,   9411.7388703 ,
